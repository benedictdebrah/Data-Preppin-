# %%
#importing libraries
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('PD 2023 Wk 1 Input.csv')
data.shape
# Out:
# (365, 5)

# %%
data.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person  \
# 0  DTB-716-679-576   1448         100001                    2
# 1   DS-795-814-303   7839         100001                    2
# 2  DSB-807-592-406   5520         100005                    1
# 3   DS-367-545-264   7957         100007                    2
# 4  DSB-474-374-857   5375         100000                    2
#
#       Transaction Date
# 0  20/03/2023 00:00:00
# 1  15/11/2023 00:00:00
# 2  14/07/2023 00:00:00
# 3  18/08/2023 00:00:00
# 4  26/08/2023 00:00:00

# %%
target = pd.read_csv('Targets.csv')
target.shape
# Out:
# (2, 5)

# %%
target.head()
# Out:
#   Online or In-Person     Q1     Q2     Q3     Q4
# 0              Online  72500  70000  60000  60000
# 1           In-Person  75000  70000  70000  60000

# %%
#Rename the values in the Online or In-person field, Online of the 1 values and In-Person for the 2 values
target['Online or In-Person'] = target['Online or In-Person'].map({'Online':'1','In-Person':'2'})

# %%
target
# Out:
#   Online or In-Person     Q1     Q2     Q3     Q4
# 0                   1  72500  70000  60000  60000
# 1                   2  75000  70000  70000  60000

# %%
#Change the date to be the quarter
data['Quarter'] =pd.PeriodIndex(data['Transaction Date'],freq='Q')
data['Quarter'] = data['Quarter'].astype(str)

# %%
data['Quarter'] = data['Quarter'].str[-1]

# %%
#dropping transaction column
data.drop(columns='Transaction Date',inplace=True)

# %%
data.head()
# Out:
#   Transaction Code  Value  Customer Code  Online or In-Person Quarter
# 0  DTB-716-679-576   1448         100001                    2       1
# 1   DS-795-814-303   7839         100001                    2       4
# 2  DSB-807-592-406   5520         100005                    1       3
# 3   DS-367-545-264   7957         100007                    2       3
# 4  DSB-474-374-857   5375         100000                    2       3

# %%
target = target.rename(columns={"Q1": 1, "Q2": 2,"Q3": 3,"Q4": 4})

# %%
target.head()
# Out:
#   Online or In-Person      1      2      3      4
# 0                   1  72500  70000  60000  60000
# 1                   2  75000  70000  70000  60000

# %%
target['Online or In-Person'] = target['Online or In-Person'].astype(int)

# %%
inner_join = pd.merge(data, 
                      target, 
                      on ='Online or In-Person', 
                      how ='inner')

# %%
inner_join.shape
# Out:
# (365, 9)

# %%
#finding the right data for q1
for index, row in inner_join.iterrows():
    if '1' in row['Quarter']:
         df1 = print(index, row['Transaction Code'], row['Value'],
              row['Customer Code'], row['Online or In-Person'], row['Quarter'],row[1])
# Out:
# 0 DTB-716-679-576 1448 100001 2 1 75000
# 7 DTB-625-200-665 8772 100009 2 1 75000
# 8 DTB-395-412-673 4305 100000 2 1 75000
# 9 DS-827-477-284 6423 100002 2 1 75000
# 11 DTB-148-931-227 4684 100010 2 1 75000
# 13 DTB-879-606-315 2006 100002 2 1 75000
# 22 DTB-363-112-552 3723 100008 2 1 75000
# 28 DTB-472-169-553 5861 100009 2 1 75000
# 29 DS-965-495-114 2461 100004 2 1 75000
# 31 DS-945-974-199 6413 100000 2 1 75000
# 37 DSB-950-437-523 6107 100001 2 1 75000
# 39 DTB-428-277-419 6015 100005 2 1 75000
# 40 DTB-944-219-439 5271 100001 2 1 75000
# 43 DS-679-253-456 1525 100000 2 1 75000
# 46 DS-866-694-363 1943 100003 2 1 75000
# 56 DTB-497-482-165 5156 100005 2 1 75000
# 57 DSB-585-219-171 9038 100010 2 1 75000
# 59 DSB-810-110-106 8010 100001 2 1 75000
# 62 DTB-576-237-983 8591 100010 2 1 75000
# 68 DTB-328-895-365 7883 100000 2 1 75000
# 70 DTB-764-607-507 3688 100003 2 1 75000
# 73 DS-125-329-654 3584 100000 2 1 75000
# 103 DS-752-559-243 6584 100010 2 1 75000
# ...

# %%
# Create an empty dataframe
df1 = pd.DataFrame(columns=['Index', 'Transaction Code', 'Value', 'Customer Code', 'Online or In-Person', 'Quarter'])

# Iterate through the rows of the inner_join dataframe
for index, row in inner_join.iterrows():
    if '1' in row['Quarter']:
        # Append the row to the df1 dataframe
        df1 = df1.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
              'Quarter':row['Quarter'],'Quarterly Target':row[1]}, ignore_index=True)

# Print the df1 dataframe
df1.head()
# Out:
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\4185647990.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\4185647990.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\4185647990.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# Create an empty dataframe for quaarter 2
df2 = pd.DataFrame(columns=['Index', 'Transaction Code', 'Value', 'Customer Code', 'Online or In-Person', 'Quarter'])

# Iterate through the rows of the inner_join dataframe
for index, row in inner_join.iterrows():
    if '2' in row['Quarter']:
        # Append the row to the df1 dataframe
        df2 = df2.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
              'Quarter':row['Quarter'],'Quarterly Target':row[2]}, ignore_index=True)

# Print the df1 dataframe
df2.head()
# Out:
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\1058234475.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\1058234475.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\1058234475.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# Create an empty dataframe for quarter 3
df3 = pd.DataFrame(columns=['Index', 'Transaction Code', 'Value', 'Customer Code', 'Online or In-Person', 'Quarter'])

# Iterate through the rows of the inner_join dataframe
for index, row in inner_join.iterrows():
    if '3' in row['Quarter']:
        # Append the row to the df1 dataframe
        df3 = df3.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
              'Quarter':row['Quarter'],'Quarterly Target':row[3]}, ignore_index=True)

# Print the df1 dataframe
df3.head()
# Out:
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\2702180509.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\2702180509.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df3.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\2702180509.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
# Create an empty dataframe for quarter 4
df4 = pd.DataFrame(columns=['Index', 'Transaction Code', 'Value', 'Customer Code', 'Online or In-Person', 'Quarter'])

# Iterate through the rows of the inner_join dataframe
for index, row in inner_join.iterrows():
    if '4' in row['Quarter']:
        # Append the row to the df1 dataframe
        df4 = df4.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
              'Quarter':row['Quarter'],'Quarterly Target':row[4]}, ignore_index=True)

# Print the df1 dataframe
df4.head()
# Out:
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\2339871316.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df4.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\2339871316.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4 = df4.append({'Index':index, 'Transaction Code':row['Transaction Code'], 'Value':row['Value'], 'Customer Code':row['Customer Code'], 'Online or In-Person':row['Online or In-Person'],
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\2339871316.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# make a single dataset out of our outputs

# %%
result = pd.concat([df1, df2, df3, df4])

# %%
result
# Out:
#    Index Transaction Code Value Customer Code Online or In-Person Quarter  \
# 0      0  DTB-716-679-576  1448        100001                   2       1
# 1      7  DTB-625-200-665  8772        100009                   2       1
# 2      8  DTB-395-412-673  4305        100000                   2       1
# 3      9   DS-827-477-284  6423        100002                   2       1
# 4     11  DTB-148-931-227  4684        100010                   2       1
# ..   ...              ...   ...           ...                 ...     ...
# 80   353  DTB-667-521-670  4488        100001                   1       4
# 81   355  DSB-618-298-395  9280        100008                   1       4
# 82   360   DS-236-990-748  7767        100001                   1       4
# 83   361  DSB-879-328-611  8316        100008                   1       4
# 84   363   DS-551-937-380   475        100002                   1       4
#
#     Quarterly Target
# 0            75000.0
# 1            75000.0
# ...

# %%
result = result.sort_values(by='Index')

# %%
result
# Out:
#     Index Transaction Code Value Customer Code Online or In-Person Quarter  \
# 0       0  DTB-716-679-576  1448        100001                   2       1
# 0       1   DS-795-814-303  7839        100001                   2       4
# 0       2   DS-367-545-264  7957        100007                   2       3
# 1       3  DSB-474-374-857  5375        100000                   2       3
# 0       4   DS-213-969-866  2321        100007                   2       2
# ..    ...              ...   ...           ...                 ...     ...
# 82    360   DS-236-990-748  7767        100001                   1       4
# 83    361  DSB-879-328-611  8316        100008                   1       4
# 83    362  DTB-116-439-102  6708        100001                   1       1
# 84    363   DS-551-937-380   475        100002                   1       4
# 102   364   DS-976-542-770  7364        100009                   1       3
#
#      Quarterly Target
# 0             75000.0
# ...

# %%
#making changes to the Online or In-Person	column-
result['Online or In-Person'] = result['Online or In-Person'].map({1:'Online',2:'In-Person'})

# %%
result
# Out:
#     Index Transaction Code Value Customer Code Online or In-Person Quarter  \
# 0       0  DTB-716-679-576  1448        100001           In-Person       1
# 0       1   DS-795-814-303  7839        100001           In-Person       4
# 0       2   DS-367-545-264  7957        100007           In-Person       3
# 1       3  DSB-474-374-857  5375        100000           In-Person       3
# 0       4   DS-213-969-866  2321        100007           In-Person       2
# ..    ...              ...   ...           ...                 ...     ...
# 82    360   DS-236-990-748  7767        100001              Online       4
# 83    361  DSB-879-328-611  8316        100008              Online       4
# 83    362  DTB-116-439-102  6708        100001              Online       1
# 84    363   DS-551-937-380   475        100002              Online       4
# 102   364   DS-976-542-770  7364        100009              Online       3
#
#      Quarterly Target
# 0             75000.0
# ...

# %%
output = result[['Online or In-Person','Quarter','Value', 'Quarterly Target']]

# %%
#output.info()
output['Value'] = output['Value'].astype(int)
output['Quarterly Target'] = output['Quarterly Target'].astype(int)
# Out:
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\487628929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['Value'] = output['Value'].astype(int)
# C:\Users\Benedict\AppData\Local\Temp\ipykernel_2672\487628929.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output['Quarterly Target'] = output['Quarterly Target'].astype(int)

# %%
output
# Out:
#     Online or In-Person Quarter  Value  Quarterly Target
# 0             In-Person       1   1448             75000
# 0             In-Person       4   7839             60000
# 0             In-Person       3   7957             70000
# 1             In-Person       3   5375             70000
# 0             In-Person       2   2321             70000
# ..                  ...     ...    ...               ...
# 82               Online       4   7767             60000
# 83               Online       4   8316             60000
# 83               Online       1   6708             72500
# 84               Online       4    475             60000
# 102              Online       3   7364             60000
#
# [365 rows x 4 columns]

# %%
final = output.groupby(['Online or In-Person','Quarter','Quarterly Target'])['Value'].sum().reset_index()

# %%
final = final[['Online or In-Person', 'Quarter','Value','Quarterly Target']]

# %%
final
# Out:
#   Online or In-Person Quarter   Value  Quarterly Target
# 0           In-Person       1  184553             75000
# 1           In-Person       2  243330             70000
# 2           In-Person       3  254294             70000
# 3           In-Person       4  266570             60000
# 4              Online       1  226287             72500
# 5              Online       2  200131             70000
# 6              Online       3  257709             60000
# 7              Online       4  169793             60000

# %%
final['Variance to target'] = final['Value'] - final['Quarterly Target']

# %%
final
# Out:
#   Online or In-Person Quarter   Value  Quarterly Target  Variance to target
# 0           In-Person       1  184553             75000              109553
# 1           In-Person       2  243330             70000              173330
# 2           In-Person       3  254294             70000              184294
# 3           In-Person       4  266570             60000              206570
# 4              Online       1  226287             72500              153787
# 5              Online       2  200131             70000              130131
# 6              Online       3  257709             60000              197709
# 7              Online       4  169793             60000              109793
